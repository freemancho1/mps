# %%
from mps.config import cfg

# %%
cfg.sys.phase
# Out:
# 2

# %%
cfg.train
# Out:
# _TrainConfig(lstm_settings=_LSTMConfig(input_size=14, hidden_size=64, num_layers=2, num_classes=2, dropout=0.2), cnn_settings=_CNNConfig(in_channels=5, num_classes=2, dropout=0.2), hyper_params=_HyperparameterConfig(epochs=50, batch_size=64, lr=0.0001, weight_decay=0.0001, val_ratio=0.2, patience=10))
