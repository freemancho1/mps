# %%
from mps.sys import config as cfg

# %%
cfg.run
# Out:
# RunBacktestConfig(tickers=['005930'], start_date='2025-01-01', end_date='2025-12-31', capital=10000000.0, key=RunBacktestConfig._key(), msg=RunBacktestConfig._msg())

# %%
cfg.run.key
# Out:
# RunBacktestConfig._key()

# %%
cfg.run.key.ticker
# Out:
# '--ticker'

# %%
cfg.run.msg.title
# Out:
# 'MPS Phase 1 백테스트'

# %%
cfg.run.key.ticker = "new key"
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cfg.run.key.ticker = "new key"
#
# File <string>:15, in __create_fn__.<locals>.__setattr__(self, name, value)
#      13 'Could not get source, probably due dynamically evaluated source code.'
#
# FrozenInstanceError: cannot assign to field 'ticker'

# %%
cfg.run.capital = 10.0
