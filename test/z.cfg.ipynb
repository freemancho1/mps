# %%
from mps.core.config import cfg

# %%
cfg
# Out:
# _Config(_root_dir=PosixPath('/home/freeman/projects/mps'), run=_RunConfig(tickers=['005930'], start_date_str='20250101', end_date_str='20251231', init_capital=10000000.0), sys=_SystemConfig(phase=2, version='v3'), path=_PathConfig(store=PosixPath('/home/freeman/projects/mps/artifacts/v3/store'), store_fname='minute_bars.parquet'))

# %%
cfg.path.store, cfg.path.store_fname
# Out:
# (PosixPath('/home/freeman/projects/mps/artifacts/v3/store'),
#  'minute_bars.parquet')
