# %%
from mps.core.config import msg

# %%
from mps.core.utils import logger

# %%
logger.debug("debug")
# Out:
# 2026-06-21 20:42:32.888    DEBUG: debug

# %%
logger.debug("debug")
logger.info("debug")
logger.point("debug")
logger.warning("debug")
logger.error("debug")
logger.critical("debug")
# Out:
# 2026-06-21 20:43:16.464    DEBUG: debug
# 2026-06-21 20:43:16.464     INFO: debug
# 2026-06-21 20:43:16.464    POINT: debug
# 2026-06-21 20:43:16.464  WARNING: debug
# 2026-06-21 20:43:16.464    ERROR: debug
# 2026-06-21 20:43:16.464 CRITICAL: debug
