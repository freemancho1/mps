# %%
from mps.core.libs import DictDot

# %%
cfg = DictDot(
    name="MPS",
    risk=DictDot(
        sl=-0.01,
        tp=0.02,
    ),
)

# %%
cfg
# Out:
# DictDot({'name': 'MPS', 'risk': DictDot({'sl': -0.01, 'tp': 0.02})})

# %%
cfg.name
# Out:
# 'MPS'
