# %%
from mps.config import cfg

# %%
cfg
# Out:
# _Config(_root_dir=PosixPath('/home/freeman/projects'), run=_RunConfig(tickers=['005930'], start_date_str='20250101', end_date_str='20251231', init_capital=10000000.0), sys=_SystemConfig(name='MPS', phase=2, version='v3', seed=42, zero=1e-08, timezone=zoneinfo.ZoneInfo(key='Asia/Seoul'), date_format='%Y%m%d', time_format='%H:%M:%S', force_data_refresh=False, torch_device='cuda'), path=_PathConfig(_root_dir=PosixPath('/home/freeman/projects/mps/src/v3')), kis=_KisApiConfig(), train=_TrainConfig(lstm_settings=_LSTMConfig(input_size=14, hidden_size=64, num_layers=2, num_classes=2, dropout=0.2), cnn_settings=_CNNConfig(in_channels=5, num_classes=2, dropout=0.2), hyper=_HyperparameterConfig(epochs=50, batch_size=64, lr=0.0001, weight_decay=0.0001, val_ratio=0.2, patience=10)), key=_KeyValues(capital='--capital', end='--end', start='--start', ticker='--ticker'), str=_StringValue())

# %%
cfg.path
# Out:
# _PathConfig(_root_dir=PosixPath('/home/freeman/projects/mps/src'))

# %%
from mps.freelibs import logger

# %%
logger.debug("aaaaaaaaaaaaaaaaaaaaaaaaaaa")
logger.debug("warrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr")
logger.warning("warrrninggggggggggggggggggggggggg")
logger.error("errrrrrro0rrrrrorrrrrorrr")
logger.critical("cffcfdffff")
